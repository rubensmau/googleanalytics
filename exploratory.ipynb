# %%
from fastai.basics import *
from IPython.core.pylabtools import figsize
import gc, json
from pandas.io.json import json_normalize
from datetime import datetime
#import lightgbm as lgb
gc.enable()
# Out:
# /home/rubens/miniconda3/lib/python3.8/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
def load_tr(csv_path, nrows=None, skiprows=None):
    
    usecols = ['channelGrouping', 'date', 'device',
       'fullVisitorId', 'geoNetwork', 'totals',
       'trafficSource', 'visitId', 'visitNumber', 'visitStartTime' ]
    json_cols = ['device', 'geoNetwork', 'totals', 'trafficSource']
    ans = pd.DataFrame()
    trs = pd.read_csv(csv_path, 
            sep=',',
            usecols = usecols,
            converters={column: json.loads for column in json_cols}, 
            dtype={'fullVisitorId': 'str',
                  'channelGrouping': 'str',                 
                  'visitId':'int',
                  'visitNumber':'int',
                  'visitStartTime':'int'}, 
            parse_dates=['date'], 
            chunksize=100000,
            nrows=nrows,
            skiprows=skiprows)
    
    for tr in trs:
        tr.reset_index(drop=True, inplace=True)
        for column in json_cols:
            column_as_tr = json_normalize(tr[column])
            column_as_tr.columns = [f"{column}_{subcolumn}" for subcolumn in column_as_tr.columns]
            tr = tr.drop(column, axis=1).merge(column_as_tr, right_index=True, left_index=True)

        print(f"Loaded {os.path.basename(csv_path)}. Shape: {tr.shape}")
        tr_chunk = tr  #[features]
        del tr
        gc.collect()
        ans = pd.concat([ans, tr_chunk], axis=0).reset_index(drop=True)
        #print(ans.shape)
    return ans

# %%
PATH=Path('/home/rubens/googleanalytics/data')

tr = load_tr(PATH/'sample.txt')
print('train date:', min(tr['date']), 'to', max(tr['date']))
# Out:
# <ipython-input-2-198ed635a259>:25: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   column_as_tr = json_normalize(tr[column])
# Loaded sample.txt. Shape: (9999, 56)
# train date: 2016-09-02 00:00:00 to 2017-11-30 00:00:00

# %%
tr.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'visitId', 'visitNumber',
#        'visitStartTime', 'device_browser', 'device_browserVersion',
#        'device_browserSize', 'device_operatingSystem',
#        'device_operatingSystemVersion', 'device_isMobile',
#        'device_mobileDeviceBranding', 'device_mobileDeviceModel',
#        'device_mobileInputSelector', 'device_mobileDeviceInfo',
#        'device_mobileDeviceMarketingName', 'device_flashVersion',
#        'device_language', 'device_screenColors', 'device_screenResolution',
#        'device_deviceCategory', 'geoNetwork_continent',
#        'geoNetwork_subContinent', 'geoNetwork_country', 'geoNetwork_region',
#        'geoNetwork_metro', 'geoNetwork_city', 'geoNetwork_cityId',
#        'geoNetwork_networkDomain', 'geoNetwork_latitude',
#        'geoNetwork_longitude', 'geoNetwork_networkLocation', 'totals_visits',
#        'totals_hits', 'totals_pageviews', 'totals_bounces', 'totals_newVisits',
#        'totals_sessionQualityDim', 'totals_timeOnSite', 'totals_transactions',
#        'totals_transactionRevenue', 'totals_totalTransactionRevenue',
#        'trafficSource_campaign', 'trafficSource_source',
#        'trafficSource_medium', 'trafficSource_keyword',
#        'trafficSource_adwordsClickInfo.criteriaParameters',
#        'trafficSource_referralPath', 'trafficSource_isTrueDirect',
#        'trafficSource_adContent', 'trafficSource_adwordsClickInfo.page',
#        'trafficSource_adwordsClickInfo.slot',
#        'trafficSource_adwordsClickInfo.gclId',
#        'trafficSource_adwordsClickInfo.adNetworkType',
#        'trafficSource_adwordsClickInfo.isVideoAd'],
#       dtype='object')

# %%
#correct dtypes
tr["date"] = pd.to_datetime(tr["date"], infer_datetime_format=True, format="%Y%m%d")
tr['totals_hits'] = tr['totals_hits'].astype(float)
tr['totals_pageviews'] = tr['totals_pageviews'].astype(float)
tr['totals_timeOnSite'] = tr['totals_timeOnSite'].astype(float)
tr['totals_newVisits'] = tr['totals_newVisits'].astype(float)
tr['totals_transactions'] = tr['totals_transactions'].astype(float)
tr['device_isMobile'] = tr['device_isMobile'].astype(bool)
tr['trafficSource_isTrueDirect'] = tr['trafficSource_isTrueDirect'].astype(bool)

# %%
#replace all empty fields with NaN
Nulls = ['(not set)', 'not available in demo dataset', '(not provided)', 
         'unknown.unknown', '/', 'Not Socially Engaged']
for null in Nulls:    
    tr.replace(null, np.nan, inplace=True)

# %%
# target
tr['totals_totalTransactionRevenue'] = tr['totals_totalTransactionRevenue'].astype(float)
tr['totals_totalTransactionRevenue'].fillna(0, inplace=True)
target = tr['totals_totalTransactionRevenue']

# %%
tr.shape
# Out:
# (9999, 56)

# %%
tr.head(10).T
# Out:
#                                                                      0  \
# channelGrouping                                         Organic Search
# date                                               2017-10-16 00:00:00
# fullVisitorId                                      3162355547410993243
# visitId                                                     1508198450
# visitNumber                                                          1
# visitStartTime                                              1508198450
# device_browser                                                 Firefox
# device_browserVersion                                              NaN
# device_browserSize                                                 NaN
# device_operatingSystem                                         Windows
# device_operatingSystemVersion                                      NaN
# device_isMobile                                                  False
# device_mobileDeviceBranding                                        NaN
# device_mobileDeviceModel                                           NaN
# device_mobileInputSelector                                         NaN
# device_mobileDeviceInfo                                            NaN
# device_mobileDeviceMarketingName                                   NaN
# device_flashVersion                                                NaN
# device_language                                                    NaN
# device_screenColors                                                NaN
# device_screenResolution                                            NaN
# device_deviceCategory                                          desktop
# geoNetwork_continent                                            Europe
# geoNetwork_subContinent                                 Western Europe
# geoNetwork_country                                             Germany
# geoNetwork_region                                                  NaN
# geoNetwork_metro                                                   NaN
# geoNetwork_city                                                    NaN
# geoNetwork_cityId                                                  NaN
# geoNetwork_networkDomain                                           NaN
# geoNetwork_latitude                                                NaN
# geoNetwork_longitude                                               NaN
# geoNetwork_networkLocation                                         NaN
# totals_visits                                                        1
# totals_hits                                                        1.0
# totals_pageviews                                                   1.0
# totals_bounces                                                       1
# totals_newVisits                                                   1.0
# totals_sessionQualityDim                                             1
# totals_timeOnSite                                                  NaN
# totals_transactions                                                NaN
# totals_transactionRevenue                                          NaN
# totals_totalTransactionRevenue                                     0.0
# trafficSource_campaign                                             NaN
# trafficSource_source                                            google
# trafficSource_medium                                           organic
# trafficSource_keyword                                     water bottle
# trafficSource_adwordsClickInfo.criteriaParameters                  NaN
# trafficSource_referralPath                                         NaN
# trafficSource_isTrueDirect                                        True
# trafficSource_adContent                                            NaN
# trafficSource_adwordsClickInfo.page                                NaN
# trafficSource_adwordsClickInfo.slot                                NaN
# trafficSource_adwordsClickInfo.gclId                               NaN
# trafficSource_adwordsClickInfo.adNetworkType                       NaN
# trafficSource_adwordsClickInfo.isVideoAd                           NaN
#
#                                                                                                                   1  \
# channelGrouping                                                                                            Referral
# date                                                                                            2017-10-16 00:00:00
# fullVisitorId                                                                                   8934116514970143966
# visitId                                                                                                  1508176307
# visitNumber                                                                                                       6
# visitStartTime                                                                                           1508176307
# device_browser                                                                                               Chrome
# device_browserVersion                                                                                           NaN
# device_browserSize                                                                                              NaN
# device_operatingSystem                                                                                    Chrome OS
# device_operatingSystemVersion                                                                                   NaN
# device_isMobile                                                                                               False
# device_mobileDeviceBranding                                                                                     NaN
# device_mobileDeviceModel                                                                                        NaN
# device_mobileInputSelector                                                                                      NaN
# device_mobileDeviceInfo                                                                                         NaN
# device_mobileDeviceMarketingName                                                                                NaN
# device_flashVersion                                                                                             NaN
# device_language                                                                                                 NaN
# device_screenColors                                                                                             NaN
# device_screenResolution                                                                                         NaN
# device_deviceCategory                                                                                       desktop
# geoNetwork_continent                                                                                       Americas
# geoNetwork_subContinent                                                                            Northern America
# geoNetwork_country                                                                                    United States
# geoNetwork_region                                                                                        California
# geoNetwork_metro                                                                  San Francisco-Oakland-San Jose CA
# geoNetwork_city                                                                                           Cupertino
# geoNetwork_cityId                                                                                               NaN
# geoNetwork_networkDomain                                                                                        NaN
# geoNetwork_latitude                                                                                             NaN
# geoNetwork_longitude                                                                                            NaN
# geoNetwork_networkLocation                                                                                      NaN
# totals_visits                                                                                                     1
# totals_hits                                                                                                     2.0
# totals_pageviews                                                                                                2.0
# totals_bounces                                                                                                  NaN
# totals_newVisits                                                                                                NaN
# totals_sessionQualityDim                                                                                          2
# totals_timeOnSite                                                                                              28.0
# totals_transactions                                                                                             NaN
# totals_transactionRevenue                                                                                       NaN
# totals_totalTransactionRevenue                                                                                  0.0
# trafficSource_campaign                                                                                          NaN
# trafficSource_source                                                                               sites.google.com
# trafficSource_medium                                                                                       referral
# trafficSource_keyword                                                                                           NaN
# trafficSource_adwordsClickInfo.criteriaParameters                                                               NaN
# trafficSource_referralPath                         /a/google.com/transportation/mtv-services/bikes/bike2workmay2016
# trafficSource_isTrueDirect                                                                                     True
# trafficSource_adContent                                                                                         NaN
# trafficSource_adwordsClickInfo.page                                                                             NaN
# trafficSource_adwordsClickInfo.slot                                                                             NaN
# trafficSource_adwordsClickInfo.gclId                                                                            NaN
# trafficSource_adwordsClickInfo.adNetworkType                                                                    NaN
# trafficSource_adwordsClickInfo.isVideoAd                                                                        NaN
#
#                                                                      2  \
# channelGrouping                                                 Direct
# date                                               2017-10-16 00:00:00
# fullVisitorId                                      7992466427990357681
# visitId                                                     1508201613
# visitNumber                                                          1
# visitStartTime                                              1508201613
# device_browser                                                  Chrome
# device_browserVersion                                              NaN
# device_browserSize                                                 NaN
# device_operatingSystem                                         Android
# device_operatingSystemVersion                                      NaN
# device_isMobile                                                   True
# device_mobileDeviceBranding                                        NaN
# device_mobileDeviceModel                                           NaN
# device_mobileInputSelector                                         NaN
# device_mobileDeviceInfo                                            NaN
# device_mobileDeviceMarketingName                                   NaN
# device_flashVersion                                                NaN
# device_language                                                    NaN
# device_screenColors                                                NaN
# device_screenResolution                                            NaN
# device_deviceCategory                                           mobile
# geoNetwork_continent                                          Americas
# geoNetwork_subContinent                               Northern America
# geoNetwork_country                                       United States
# geoNetwork_region                                                  NaN
# geoNetwork_metro                                                   NaN
# geoNetwork_city                                                    NaN
# geoNetwork_cityId                                                  NaN
# geoNetwork_networkDomain                           windjammercable.net
# geoNetwork_latitude                                                NaN
# geoNetwork_longitude                                               NaN
# geoNetwork_networkLocation                                         NaN
# totals_visits                                                        1
# totals_hits                                                        2.0
# totals_pageviews                                                   2.0
# totals_bounces                                                     NaN
# totals_newVisits                                                   1.0
# totals_sessionQualityDim                                             1
# totals_timeOnSite                                                 38.0
# totals_transactions                                                NaN
# totals_transactionRevenue                                          NaN
# totals_totalTransactionRevenue                                     0.0
# trafficSource_campaign                                             NaN
# trafficSource_source                                          (direct)
# trafficSource_medium                                            (none)
# trafficSource_keyword                                              NaN
# trafficSource_adwordsClickInfo.criteriaParameters                  NaN
# trafficSource_referralPath                                         NaN
# trafficSource_isTrueDirect                                        True
# trafficSource_adContent                                            NaN
# trafficSource_adwordsClickInfo.page                                NaN
# trafficSource_adwordsClickInfo.slot                                NaN
# trafficSource_adwordsClickInfo.gclId                               NaN
# trafficSource_adwordsClickInfo.adNetworkType                       NaN
# trafficSource_adwordsClickInfo.isVideoAd                           NaN
#
#                                                                      3  \
# channelGrouping                                         Organic Search
# date                                               2017-10-16 00:00:00
# fullVisitorId                                      9075655783635761930
# visitId                                                     1508169851
# visitNumber                                                          1
# visitStartTime                                              1508169851
# device_browser                                                  Chrome
# device_browserVersion                                              NaN
# device_browserSize                                                 NaN
# device_operatingSystem                                         Windows
# device_operatingSystemVersion                                      NaN
# device_isMobile                                                  False
# device_mobileDeviceBranding                                        NaN
# device_mobileDeviceModel                                           NaN
# device_mobileInputSelector                                         NaN
# device_mobileDeviceInfo                                            NaN
# device_mobileDeviceMarketingName                                   NaN
# device_flashVersion                                                NaN
# device_language                                                    NaN
# device_screenColors                                                NaN
# device_screenResolution                                            NaN
# device_deviceCategory                                          desktop
# geoNetwork_continent                                              Asia
# geoNetwork_subContinent                                   Western Asia
# geoNetwork_country                                              Turkey
# geoNetwork_region                                                  NaN
# geoNetwork_metro                                                   NaN
# geoNetwork_city                                                    NaN
# geoNetwork_cityId                                                  NaN
# geoNetwork_networkDomain                                           NaN
# geoNetwork_latitude                                                NaN
# geoNetwork_longitude                                               NaN
# geoNetwork_networkLocation                                         NaN
# totals_visits                                                        1
# totals_hits                                                        2.0
# totals_pageviews                                                   2.0
# totals_bounces                                                     NaN
# totals_newVisits                                                   1.0
# totals_sessionQualityDim                                             1
# totals_timeOnSite                                                  1.0
# totals_transactions                                                NaN
# totals_transactionRevenue                                          NaN
# totals_totalTransactionRevenue                                     0.0
# trafficSource_campaign                                             NaN
# trafficSource_source                                            google
# trafficSource_medium                                           organic
# trafficSource_keyword                                              NaN
# trafficSource_adwordsClickInfo.criteriaParameters                  NaN
# trafficSource_referralPath                                         NaN
# trafficSource_isTrueDirect                                        True
# trafficSource_adContent                                            NaN
# trafficSource_adwordsClickInfo.page                                NaN
# trafficSource_adwordsClickInfo.slot                                NaN
# trafficSource_adwordsClickInfo.gclId                               NaN
# trafficSource_adwordsClickInfo.adNetworkType                       NaN
# trafficSource_adwordsClickInfo.isVideoAd                           NaN
#
#                                                                        4  \
# channelGrouping                                           Organic Search
# date                                                 2017-10-16 00:00:00
# fullVisitorId                                        6960673291025684308
# visitId                                                       1508190552
# visitNumber                                                            1
# visitStartTime                                                1508190552
# device_browser                                                    Chrome
# device_browserVersion                                                NaN
# device_browserSize                                                   NaN
# device_operatingSystem                                           Windows
# device_operatingSystemVersion                                        NaN
# device_isMobile                                                    False
# device_mobileDeviceBranding                                          NaN
# device_mobileDeviceModel                                             NaN
# device_mobileInputSelector                                           NaN
# device_mobileDeviceInfo                                              NaN
# device_mobileDeviceMarketingName                                     NaN
# device_flashVersion                                                  NaN
# device_language                                                      NaN
# device_screenColors                                                  NaN
# device_screenResolution                                              NaN
# device_deviceCategory                                            desktop
# geoNetwork_continent                                            Americas
# geoNetwork_subContinent                                  Central America
# geoNetwork_country                                                Mexico
# geoNetwork_region                                                    NaN
# geoNetwork_metro                                                     NaN
# geoNetwork_city                                                      NaN
# geoNetwork_cityId                                                    NaN
# geoNetwork_networkDomain                           prod-infinitum.com.mx
# geoNetwork_latitude                                                  NaN
# geoNetwork_longitude                                                 NaN
# geoNetwork_networkLocation                                           NaN
# totals_visits                                                          1
# totals_hits                                                          2.0
# totals_pageviews                                                     2.0
# totals_bounces                                                       NaN
# totals_newVisits                                                     1.0
# totals_sessionQualityDim                                               1
# totals_timeOnSite                                                   52.0
# totals_transactions                                                  NaN
# totals_transactionRevenue                                            NaN
# totals_totalTransactionRevenue                                       0.0
# trafficSource_campaign                                               NaN
# trafficSource_source                                              google
# trafficSource_medium                                             organic
# trafficSource_keyword                                                NaN
# trafficSource_adwordsClickInfo.criteriaParameters                    NaN
# trafficSource_referralPath                                           NaN
# trafficSource_isTrueDirect                                          True
# trafficSource_adContent                                              NaN
# trafficSource_adwordsClickInfo.page                                  NaN
# trafficSource_adwordsClickInfo.slot                                  NaN
# trafficSource_adwordsClickInfo.gclId                                 NaN
# trafficSource_adwordsClickInfo.adNetworkType                         NaN
# trafficSource_adwordsClickInfo.isVideoAd                             NaN
#
#                                                                                    5  \
# channelGrouping                                                             Referral
# date                                                             2017-10-16 00:00:00
# fullVisitorId                                                    0166277907528479249
# visitId                                                                   1508196701
# visitNumber                                                                        1
# visitStartTime                                                            1508196701
# device_browser                                                                Chrome
# device_browserVersion                                                            NaN
# device_browserSize                                                               NaN
# device_operatingSystem                                                     Macintosh
# device_operatingSystemVersion                                                    NaN
# device_isMobile                                                                False
# device_mobileDeviceBranding                                                      NaN
# device_mobileDeviceModel                                                         NaN
# device_mobileInputSelector                                                       NaN
# device_mobileDeviceInfo                                                          NaN
# device_mobileDeviceMarketingName                                                 NaN
# device_flashVersion                                                              NaN
# device_language                                                                  NaN
# device_screenColors                                                              NaN
# device_screenResolution                                                          NaN
# device_deviceCategory                                                        desktop
# geoNetwork_continent                                                        Americas
# geoNetwork_subContinent                                             Northern America
# geoNetwork_country                                                     United States
# geoNetwork_region                                                         California
# geoNetwork_metro                                   San Francisco-Oakland-San Jose CA
# geoNetwork_city                                                        San Francisco
# geoNetwork_cityId                                                                NaN
# geoNetwork_networkDomain                                                         NaN
# geoNetwork_latitude                                                              NaN
# geoNetwork_longitude                                                             NaN
# geoNetwork_networkLocation                                                       NaN
# totals_visits                                                                      1
# totals_hits                                                                      2.0
# totals_pageviews                                                                 2.0
# totals_bounces                                                                   NaN
# totals_newVisits                                                                 1.0
# totals_sessionQualityDim                                                           2
# totals_timeOnSite                                                               12.0
# totals_transactions                                                              NaN
# totals_transactionRevenue                                                        NaN
# totals_totalTransactionRevenue                                                   0.0
# trafficSource_campaign                                                           NaN
# trafficSource_source                                                        (direct)
# trafficSource_medium                                                          (none)
# trafficSource_keyword                                                            NaN
# trafficSource_adwordsClickInfo.criteriaParameters                                NaN
# trafficSource_referralPath                                               /offer/2145
# trafficSource_isTrueDirect                                                      True
# trafficSource_adContent                                                          NaN
# trafficSource_adwordsClickInfo.page                                              NaN
# trafficSource_adwordsClickInfo.slot                                              NaN
# trafficSource_adwordsClickInfo.gclId                                             NaN
# trafficSource_adwordsClickInfo.adNetworkType                                     NaN
# trafficSource_adwordsClickInfo.isVideoAd                                         NaN
#
#                                                                                                         6  \
# channelGrouping                                                                                  Referral
# date                                                                                  2017-10-16 00:00:00
# fullVisitorId                                                                         8349655975937271469
# visitId                                                                                        1508152478
# visitNumber                                                                                             1
# visitStartTime                                                                                 1508152478
# device_browser                                                                                     Chrome
# device_browserVersion                                                                                 NaN
# device_browserSize                                                                                    NaN
# device_operatingSystem                                                                          Macintosh
# device_operatingSystemVersion                                                                         NaN
# device_isMobile                                                                                     False
# device_mobileDeviceBranding                                                                           NaN
# device_mobileDeviceModel                                                                              NaN
# device_mobileInputSelector                                                                            NaN
# device_mobileDeviceInfo                                                                               NaN
# device_mobileDeviceMarketingName                                                                      NaN
# device_flashVersion                                                                                   NaN
# device_language                                                                                       NaN
# device_screenColors                                                                                   NaN
# device_screenResolution                                                                               NaN
# device_deviceCategory                                                                             desktop
# geoNetwork_continent                                                                               Europe
# geoNetwork_subContinent                                                                   Northern Europe
# geoNetwork_country                                                                         United Kingdom
# geoNetwork_region                                                                                 England
# geoNetwork_metro                                                                                   London
# geoNetwork_city                                                                                    London
# geoNetwork_cityId                                                                                     NaN
# geoNetwork_networkDomain                                                                              NaN
# geoNetwork_latitude                                                                                   NaN
# geoNetwork_longitude                                                                                  NaN
# geoNetwork_networkLocation                                                                            NaN
# totals_visits                                                                                           1
# totals_hits                                                                                           2.0
# totals_pageviews                                                                                      2.0
# totals_bounces                                                                                        NaN
# totals_newVisits                                                                                      1.0
# totals_sessionQualityDim                                                                                1
# totals_timeOnSite                                                                                     9.0
# totals_transactions                                                                                   NaN
# totals_transactionRevenue                                                                             NaN
# totals_totalTransactionRevenue                                                                        0.0
# trafficSource_campaign                                                                                NaN
# trafficSource_source                                                                     sites.google.com
# trafficSource_medium                                                                             referral
# trafficSource_keyword                                                                                 NaN
# trafficSource_adwordsClickInfo.criteriaParameters                                                     NaN
# trafficSource_referralPath                         /a/google.com/nest-vision/dropcam-field-tester-program
# trafficSource_isTrueDirect                                                                           True
# trafficSource_adContent                                                                               NaN
# trafficSource_adwordsClickInfo.page                                                                   NaN
# trafficSource_adwordsClickInfo.slot                                                                   NaN
# trafficSource_adwordsClickInfo.gclId                                                                  NaN
# trafficSource_adwordsClickInfo.adNetworkType                                                          NaN
# trafficSource_adwordsClickInfo.isVideoAd                                                              NaN
#
#                                                                      7  \
# channelGrouping                                         Organic Search
# date                                               2017-10-16 00:00:00
# fullVisitorId                                      1332629902468998662
# visitId                                                     1508206208
# visitNumber                                                          1
# visitStartTime                                              1508206208
# device_browser                                                  Chrome
# device_browserVersion                                              NaN
# device_browserSize                                                 NaN
# device_operatingSystem                                         Windows
# device_operatingSystemVersion                                      NaN
# device_isMobile                                                  False
# device_mobileDeviceBranding                                        NaN
# device_mobileDeviceModel                                           NaN
# device_mobileInputSelector                                         NaN
# device_mobileDeviceInfo                                            NaN
# device_mobileDeviceMarketingName                                   NaN
# device_flashVersion                                                NaN
# device_language                                                    NaN
# device_screenColors                                                NaN
# device_screenResolution                                            NaN
# device_deviceCategory                                          desktop
# geoNetwork_continent                                            Europe
# geoNetwork_subContinent                                Northern Europe
# geoNetwork_country                                             Denmark
# geoNetwork_region                                                  NaN
# geoNetwork_metro                                                   NaN
# geoNetwork_city                                                    NaN
# geoNetwork_cityId                                                  NaN
# geoNetwork_networkDomain                                fullrate.ninja
# geoNetwork_latitude                                                NaN
# geoNetwork_longitude                                               NaN
# geoNetwork_networkLocation                                         NaN
# totals_visits                                                        1
# totals_hits                                                        2.0
# totals_pageviews                                                   2.0
# totals_bounces                                                     NaN
# totals_newVisits                                                   1.0
# totals_sessionQualityDim                                             1
# totals_timeOnSite                                                 15.0
# totals_transactions                                                NaN
# totals_transactionRevenue                                          NaN
# totals_totalTransactionRevenue                                     0.0
# trafficSource_campaign                                             NaN
# trafficSource_source                                            google
# trafficSource_medium                                           organic
# trafficSource_keyword                                              NaN
# trafficSource_adwordsClickInfo.criteriaParameters                  NaN
# trafficSource_referralPath                                         NaN
# trafficSource_isTrueDirect                                        True
# trafficSource_adContent                                            NaN
# trafficSource_adwordsClickInfo.page                                NaN
# trafficSource_adwordsClickInfo.slot                                NaN
# trafficSource_adwordsClickInfo.gclId                               NaN
# trafficSource_adwordsClickInfo.adNetworkType                       NaN
# trafficSource_adwordsClickInfo.isVideoAd                           NaN
#
#                                                                      8  \
# channelGrouping                                         Organic Search
# date                                               2017-10-16 00:00:00
# fullVisitorId                                       632878546807742341
# visitId                                                     1508207516
# visitNumber                                                          1
# visitStartTime                                              1508207516
# device_browser                                                  Chrome
# device_browserVersion                                              NaN
# device_browserSize                                                 NaN
# device_operatingSystem                                       Macintosh
# device_operatingSystemVersion                                      NaN
# device_isMobile                                                  False
# device_mobileDeviceBranding                                        NaN
# device_mobileDeviceModel                                           NaN
# device_mobileInputSelector                                         NaN
# device_mobileDeviceInfo                                            NaN
# device_mobileDeviceMarketingName                                   NaN
# device_flashVersion                                                NaN
# device_language                                                    NaN
# device_screenColors                                                NaN
# device_screenResolution                                            NaN
# device_deviceCategory                                          desktop
# geoNetwork_continent                                          Americas
# geoNetwork_subContinent                                Central America
# geoNetwork_country                                              Mexico
# geoNetwork_region                                          Mexico City
# geoNetwork_metro                                                   NaN
# geoNetwork_city                                            Mexico City
# geoNetwork_cityId                                                  NaN
# geoNetwork_networkDomain                             uninet-ide.com.mx
# geoNetwork_latitude                                                NaN
# geoNetwork_longitude                                               NaN
# geoNetwork_networkLocation                                         NaN
# totals_visits                                                        1
# totals_hits                                                        2.0
# totals_pageviews                                                   2.0
# totals_bounces                                                     NaN
# totals_newVisits                                                   1.0
# totals_sessionQualityDim                                             1
# totals_timeOnSite                                                 34.0
# totals_transactions                                                NaN
# totals_transactionRevenue                                          NaN
# totals_totalTransactionRevenue                                     0.0
# trafficSource_campaign                                             NaN
# trafficSource_source                                            google
# trafficSource_medium                                           organic
# trafficSource_keyword                                              NaN
# trafficSource_adwordsClickInfo.criteriaParameters                  NaN
# trafficSource_referralPath                                         NaN
# trafficSource_isTrueDirect                                        True
# trafficSource_adContent                                            NaN
# trafficSource_adwordsClickInfo.page                                NaN
# trafficSource_adwordsClickInfo.slot                                NaN
# trafficSource_adwordsClickInfo.gclId                               NaN
# trafficSource_adwordsClickInfo.adNetworkType                       NaN
# trafficSource_adwordsClickInfo.isVideoAd                           NaN
#
#                                                                      9
# channelGrouping                                         Organic Search
# date                                               2017-10-16 00:00:00
# fullVisitorId                                      1259490915281096752
# visitId                                                     1508165159
# visitNumber                                                          2
# visitStartTime                                              1508165159
# device_browser                                                  Safari
# device_browserVersion                                              NaN
# device_browserSize                                                 NaN
# device_operatingSystem                                             iOS
# device_operatingSystemVersion                                      NaN
# device_isMobile                                                   True
# device_mobileDeviceBranding                                        NaN
# device_mobileDeviceModel                                           NaN
# device_mobileInputSelector                                         NaN
# device_mobileDeviceInfo                                            NaN
# device_mobileDeviceMarketingName                                   NaN
# device_flashVersion                                                NaN
# device_language                                                    NaN
# device_screenColors                                                NaN
# device_screenResolution                                            NaN
# device_deviceCategory                                           mobile
# geoNetwork_continent                                            Europe
# geoNetwork_subContinent                                 Western Europe
# geoNetwork_country                                         Netherlands
# geoNetwork_region                                                  NaN
# geoNetwork_metro                                                   NaN
# geoNetwork_city                                                    NaN
# geoNetwork_cityId                                                  NaN
# geoNetwork_networkDomain                                           NaN
# geoNetwork_latitude                                                NaN
# geoNetwork_longitude                                               NaN
# geoNetwork_networkLocation                                         NaN
# totals_visits                                                        1
# totals_hits                                                        2.0
# totals_pageviews                                                   2.0
# totals_bounces                                                     NaN
# totals_newVisits                                                   NaN
# totals_sessionQualityDim                                             1
# totals_timeOnSite                                                 32.0
# totals_transactions                                                NaN
# totals_transactionRevenue                                          NaN
# totals_totalTransactionRevenue                                     0.0
# trafficSource_campaign                                             NaN
# trafficSource_source                                            google
# trafficSource_medium                                           organic
# trafficSource_keyword                                              NaN
# trafficSource_adwordsClickInfo.criteriaParameters                  NaN
# trafficSource_referralPath                                         NaN
# trafficSource_isTrueDirect                                        True
# trafficSource_adContent                                            NaN
# trafficSource_adwordsClickInfo.page                                NaN
# trafficSource_adwordsClickInfo.slot                                NaN
# trafficSource_adwordsClickInfo.gclId                               NaN
# trafficSource_adwordsClickInfo.adNetworkType                       NaN
# trafficSource_adwordsClickInfo.isVideoAd                           NaN

# %%
len(tf['fullVisitorId'].unique())
# Out:
# 9209

# %%
lista_1 = tf['fullVisitorId'].tolist()
lista_1[:3]
# Out:
# ['3162355547410993243', '8934116514970143966', '7992466427990357681']

# %%
from collections import Counter
lista_2 = [(k,v) for (k,v) in Counter(lista_1).items() if v > 1]
print(lista_2[:5])
print(len(lista_2))
# Out:
# [('8934116514970143966', 3), ('1259490915281096752', 2), ('6135613929977117121', 3), ('451521411412093630', 2), ('1172736694169070530', 2)]
# 636

# %%
### tinha 9999 ao inicio
### unicos 9209

agrupados = 0
for k,v in lista_2:
    agrupados = agrupados + v -1
agrupados
# Out:
# 790

# %%
agr1 = tf['totals_visits'].groupby(tf['fullVisitorId']).size()

# %%
grouped =tf['totals_visits'].groupby(tf['fullVisitorId'])
grouped.agg('sum')
# Out:
# fullVisitorId
# 0000245437374675368    1
# 0001191766179392657    1
# 0003631840334189025    1
# 0004374401845204055    1
# 0004803397127474847    1
#                       ..
# 9991882289486375263    1
# 9996018333110892344    1
# 9996276006553512804    1
# 99976789209401933      1
# 9999250019952621738    1
# Name: totals_visits, Length: 9209, dtype: object

# %%
total = 0
for index, val in agr1.iteritems():
    if val > 1:
        print (index, val)
        total += (val -1)
print(total)
# Out:
# 0005096736076850458 2
# 0073418482524217161 2
# 011894735283045088 2
# 0140565629086135926 2
# 0149900644897532124 2
# 0150499846330462944 2
# 0158478110531564328 2
# 0185467632009737931 2
# 020651025263954888 2
# 0279576853267254132 2
# 0336854895417907444 2
# 0349004699334148471 2
# 041127596981749178 2
# 0432894311233772163 2
# 0436481626935381424 2
# 0440206142725306353 4
# 0444330656643598066 2
# 0458033026034702579 2
# 0463325773564352787 2
# 0474510610802118753 2
# 0493329590229002952 2
# 0514591268737702944 2
# 0536897889827593448 2
# 0569086010364471094 2
# 0571826267646040000 2
# 0600369081537544060 3
# 0646300986554067228 2
# 0671849830470961386 2
# 0688527857109237010 2
# 0705846205174200943 4
# 071727516194667087 2
# 0720794097063742520 2
# 0731685071486167443 2
# 8774331583427812218 2
# 8797413957893249681 2
# 882129820489284364 2
# 8841959681496145095 2
# 8848948347318202755 2
# 8855273900292335568 2
# 8855807376521102824 2
# 8856233444713150106 2
# 8880643148370080045 2
# 8916768764889041110 2
# 8934116514970143966 3
# 8940942935340478342 2
# 8964716795786804368 2
# 8968955632695149927 2
# 8972907740126546790 2
# 9001282461458602359 2
# 9012423666164281718 2
# 9012569622109896332 2
# 9025499168203767604 2
# 9026755427576043872 2
# 9035059465382194949 2
# 9037858315748161263 2
# 9051912933872600383 2
# 9057220039439296640 2
# 908248583859984994 4
# 9094507973655418723 2
# 9095446776304862780 3
# 9150559069372796910 2
# 9183909054111424880 2
# 9227667103352942494 2
# 9235486300790671622 2
# 924003992899700756 2
# 9249130983722228273 2
# 9260734044911500546 2
# 9276283055070511394 2
# 9304150757506915907 2
# 931347274468450317 2
# 9322001897126398323 2
# 934768922582880532 3
# 9373935024551462942 2
# 9401280083867652779 2
# 9443274880685476538 2
# 9443648575010651806 2
# 9495467178674945184 3
# 95092632939782598 2
# 9520042062020210588 2
# 9530441121335470480 2
# 9531994353737308850 2
# 9534241921483581012 3
# 9543478172051431577 2
# 9548701438028456949 2
# 9549826748224805897 4
# 9551988887592455358 2
# 956106033508313065 2
# 9561649620847547675 2
# 9571787718004456601 2
# 9573295455015046471 2
# 9574054626913716676 2
# 9589306077484691572 2
# 9613982695129733485 3
# 9619025098094751734 2
# 9661755350583084444 4
# 9663100024296052839 3
# 9664150852987226340 3
# 9674234186055230919 2
# 9677433704501128274 2
# 9690068104046875289 2
# 9696514161596087648 2
# 969672293046741644 2
# 9713406509356101583 2
# 9737863308138302319 2
# 9749586512823078717 2
# 9764446941948669349 2
# 9794666581066906681 2
# 9801276214964695322 2
# 9806277676090496694 2
# 9833487197981263914 2
# 9833524792118425663 2
# 983464722036577473 2
# 9842642089556813984 2
# 9876630688828597922 3
# 9892610156901809298 2
# 9906507113699987566 2
# 9926903636596533727 2
# 9960300690080162672 2
# 9960353142606371996 2
# 9975172439416591237 2
# 9976598649992080351 2
# 9984810428491761529 2
# 790

# %%
tf.groupby('fullVisitorId').agg('totals_visits')

# %%
tf['totals_timeOnSite'].dropna().sum()
# Out:
# 1326189.0

# %%
def my_agg(x):
    names = {
        'timeOnSite_sum':  x['totals_timeOnSite'].dropna().sum(),
        'timeOnSite_min':  x['totals_timeOnSite'].dropna().min(),
        'timeOnSite_max':  x['totals_timeOnSite'].dropna().max(),
        'timeOnSite_mean': x['totals_timeOnSite'].dropna().mean()
    }
    return pd.Series (names,index=[ 'timeOnSite_sum','timeOnSite_min','timeOnSite_max',
                                 'timeOnSite_mean'])

# %%
tf =tr

tp = tf.groupby('fullVisitorId').apply(my_agg)
tp
# Out:
#                      timeOnSite_sum  timeOnSite_min  timeOnSite_max  \
# fullVisitorId
# 0000245437374675368            91.0            91.0            91.0
# 0001191766179392657             0.0             NaN             NaN
# 0003631840334189025            64.0            64.0            64.0
# 0004374401845204055           260.0           260.0           260.0
# 0004803397127474847          2890.0          2890.0          2890.0
# ...                             ...             ...             ...
# 9991882289486375263           112.0           112.0           112.0
# 9996018333110892344            98.0            98.0            98.0
# 9996276006553512804            20.0            20.0            20.0
# 99976789209401933               0.0             NaN             NaN
# 9999250019952621738             0.0             NaN             NaN
#
#                      timeOnSite_mean
# fullVisitorId
# 0000245437374675368             91.0
# 0001191766179392657              NaN
# 0003631840334189025             64.0
# 0004374401845204055            260.0
# 0004803397127474847           2890.0
# ...                              ...
# 9991882289486375263            112.0
# 9996018333110892344             98.0
# 9996276006553512804             20.0
# 99976789209401933                NaN
# 9999250019952621738              NaN
#
# [9209 rows x 4 columns]

# %%
tp
# Out:
#                      timeOnSite_sum  timeOnSite_min  timeOnSite_max  \
# fullVisitorId
# 0000245437374675368            91.0            91.0            91.0
# 0001191766179392657             0.0             NaN             NaN
# 0003631840334189025            64.0            64.0            64.0
# 0004374401845204055           260.0           260.0           260.0
# 0004803397127474847          2890.0          2890.0          2890.0
# ...                             ...             ...             ...
# 9991882289486375263           112.0           112.0           112.0
# 9996018333110892344            98.0            98.0            98.0
# 9996276006553512804            20.0            20.0            20.0
# 99976789209401933               0.0             NaN             NaN
# 9999250019952621738             0.0             NaN             NaN
#
#                      timeOnSite_mean
# fullVisitorId
# 0000245437374675368             91.0
# 0001191766179392657              NaN
# 0003631840334189025             64.0
# 0004374401845204055            260.0
# 0004803397127474847           2890.0
# ...                              ...
# 9991882289486375263            112.0
# 9996018333110892344             98.0
# 9996276006553512804             20.0
# 99976789209401933                NaN
# 9999250019952621738              NaN
#
# [9209 rows x 4 columns]

# %%
tpp= tp.reset_index()

# %%
tpp[tpp['fullVisitorId']=='8934116514970143966']
# Out:
#             fullVisitorId  timeOnSite_sum  timeOnSite_min  timeOnSite_max  \
# 8203  8934116514970143966            86.0            15.0            43.0
#
#       timeOnSite_mean
# 8203        28.666667

# %%
tr[tr['fullVisitorId']=='8934116514970143966']['totals_timeOnSite']
# Out:
# 1       28.0
# 2868    15.0
# 7755    43.0
# Name: totals_timeOnSite, dtype: float64

# %%
 tff = pd.merge(tr, tpp, left_on='fullVisitorId', right_on='fullVisitorId')

# %%
tff[tff['fullVisitorId']=='8934116514970143966'].T
# Out:
#                                                                                                                   1  \
# channelGrouping                                                                                            Referral
# date                                                                                            2017-10-16 00:00:00
# fullVisitorId                                                                                   8934116514970143966
# visitId                                                                                                  1508176307
# visitNumber                                                                                                       6
# visitStartTime                                                                                           1508176307
# device_browser                                                                                               Chrome
# device_browserVersion                                                                                           NaN
# device_browserSize                                                                                              NaN
# device_operatingSystem                                                                                    Chrome OS
# device_operatingSystemVersion                                                                                   NaN
# device_isMobile                                                                                               False
# device_mobileDeviceBranding                                                                                     NaN
# device_mobileDeviceModel                                                                                        NaN
# device_mobileInputSelector                                                                                      NaN
# device_mobileDeviceInfo                                                                                         NaN
# device_mobileDeviceMarketingName                                                                                NaN
# device_flashVersion                                                                                             NaN
# device_language                                                                                                 NaN
# device_screenColors                                                                                             NaN
# device_screenResolution                                                                                         NaN
# device_deviceCategory                                                                                       desktop
# geoNetwork_continent                                                                                       Americas
# geoNetwork_subContinent                                                                            Northern America
# geoNetwork_country                                                                                    United States
# geoNetwork_region                                                                                        California
# geoNetwork_metro                                                                  San Francisco-Oakland-San Jose CA
# geoNetwork_city                                                                                           Cupertino
# geoNetwork_cityId                                                                                               NaN
# geoNetwork_networkDomain                                                                                        NaN
# geoNetwork_latitude                                                                                             NaN
# geoNetwork_longitude                                                                                            NaN
# geoNetwork_networkLocation                                                                                      NaN
# totals_visits                                                                                                     1
# totals_hits                                                                                                     2.0
# totals_pageviews                                                                                                2.0
# totals_bounces                                                                                                  NaN
# totals_newVisits                                                                                                NaN
# totals_sessionQualityDim                                                                                          2
# totals_timeOnSite                                                                                              28.0
# totals_transactions                                                                                             NaN
# totals_transactionRevenue                                                                                       NaN
# totals_totalTransactionRevenue                                                                                  0.0
# trafficSource_campaign                                                                                          NaN
# trafficSource_source                                                                               sites.google.com
# trafficSource_medium                                                                                       referral
# trafficSource_keyword                                                                                           NaN
# trafficSource_adwordsClickInfo.criteriaParameters                                                               NaN
# trafficSource_referralPath                         /a/google.com/transportation/mtv-services/bikes/bike2workmay2016
# trafficSource_isTrueDirect                                                                                     True
# trafficSource_adContent                                                                                         NaN
# trafficSource_adwordsClickInfo.page                                                                             NaN
# trafficSource_adwordsClickInfo.slot                                                                             NaN
# trafficSource_adwordsClickInfo.gclId                                                                            NaN
# trafficSource_adwordsClickInfo.adNetworkType                                                                    NaN
# trafficSource_adwordsClickInfo.isVideoAd                                                                        NaN
# timeOnSite_sum                                                                                                 86.0
# timeOnSite_min                                                                                                 15.0
# timeOnSite_max                                                                                                 43.0
# timeOnSite_mean                                                                                           28.666667
#
#                                                                                    2  \
# channelGrouping                                                             Referral
# date                                                             2017-10-16 00:00:00
# fullVisitorId                                                    8934116514970143966
# visitId                                                                   1508160211
# visitNumber                                                                        5
# visitStartTime                                                            1508160211
# device_browser                                                                Chrome
# device_browserVersion                                                            NaN
# device_browserSize                                                               NaN
# device_operatingSystem                                                     Chrome OS
# device_operatingSystemVersion                                                    NaN
# device_isMobile                                                                False
# device_mobileDeviceBranding                                                      NaN
# device_mobileDeviceModel                                                         NaN
# device_mobileInputSelector                                                       NaN
# device_mobileDeviceInfo                                                          NaN
# device_mobileDeviceMarketingName                                                 NaN
# device_flashVersion                                                              NaN
# device_language                                                                  NaN
# device_screenColors                                                              NaN
# device_screenResolution                                                          NaN
# device_deviceCategory                                                        desktop
# geoNetwork_continent                                                        Americas
# geoNetwork_subContinent                                             Northern America
# geoNetwork_country                                                     United States
# geoNetwork_region                                                         California
# geoNetwork_metro                                   San Francisco-Oakland-San Jose CA
# geoNetwork_city                                                            Cupertino
# geoNetwork_cityId                                                                NaN
# geoNetwork_networkDomain                                                         NaN
# geoNetwork_latitude                                                              NaN
# geoNetwork_longitude                                                             NaN
# geoNetwork_networkLocation                                                       NaN
# totals_visits                                                                      1
# totals_hits                                                                      2.0
# totals_pageviews                                                                 2.0
# totals_bounces                                                                   NaN
# totals_newVisits                                                                 NaN
# totals_sessionQualityDim                                                           2
# totals_timeOnSite                                                               15.0
# totals_transactions                                                              NaN
# totals_transactionRevenue                                                        NaN
# totals_totalTransactionRevenue                                                   0.0
# trafficSource_campaign                                                           NaN
# trafficSource_source                                                        (direct)
# trafficSource_medium                                                          (none)
# trafficSource_keyword                                                            NaN
# trafficSource_adwordsClickInfo.criteriaParameters                                NaN
# trafficSource_referralPath                                                       NaN
# trafficSource_isTrueDirect                                                      True
# trafficSource_adContent                                                          NaN
# trafficSource_adwordsClickInfo.page                                              NaN
# trafficSource_adwordsClickInfo.slot                                              NaN
# trafficSource_adwordsClickInfo.gclId                                             NaN
# trafficSource_adwordsClickInfo.adNetworkType                                     NaN
# trafficSource_adwordsClickInfo.isVideoAd                                         NaN
# timeOnSite_sum                                                                  86.0
# timeOnSite_min                                                                  15.0
# timeOnSite_max                                                                  43.0
# timeOnSite_mean                                                            28.666667
#
#                                                                                    3
# channelGrouping                                                             Referral
# date                                                             2017-11-30 00:00:00
# fullVisitorId                                                    8934116514970143966
# visitId                                                                   1512072970
# visitNumber                                                                        7
# visitStartTime                                                            1512072970
# device_browser                                                                Chrome
# device_browserVersion                                                            NaN
# device_browserSize                                                               NaN
# device_operatingSystem                                                     Chrome OS
# device_operatingSystemVersion                                                    NaN
# device_isMobile                                                                False
# device_mobileDeviceBranding                                                      NaN
# device_mobileDeviceModel                                                         NaN
# device_mobileInputSelector                                                       NaN
# device_mobileDeviceInfo                                                          NaN
# device_mobileDeviceMarketingName                                                 NaN
# device_flashVersion                                                              NaN
# device_language                                                                  NaN
# device_screenColors                                                              NaN
# device_screenResolution                                                          NaN
# device_deviceCategory                                                        desktop
# geoNetwork_continent                                                        Americas
# geoNetwork_subContinent                                             Northern America
# geoNetwork_country                                                     United States
# geoNetwork_region                                                         California
# geoNetwork_metro                                   San Francisco-Oakland-San Jose CA
# geoNetwork_city                                                            Cupertino
# geoNetwork_cityId                                                                NaN
# geoNetwork_networkDomain                                                         NaN
# geoNetwork_latitude                                                              NaN
# geoNetwork_longitude                                                             NaN
# geoNetwork_networkLocation                                                       NaN
# totals_visits                                                                      1
# totals_hits                                                                      3.0
# totals_pageviews                                                                 3.0
# totals_bounces                                                                   NaN
# totals_newVisits                                                                 NaN
# totals_sessionQualityDim                                                           2
# totals_timeOnSite                                                               43.0
# totals_transactions                                                              NaN
# totals_transactionRevenue                                                        NaN
# totals_totalTransactionRevenue                                                   0.0
# trafficSource_campaign                                                           NaN
# trafficSource_source                                                        (direct)
# trafficSource_medium                                                          (none)
# trafficSource_keyword                                                            NaN
# trafficSource_adwordsClickInfo.criteriaParameters                                NaN
# trafficSource_referralPath                                                       NaN
# trafficSource_isTrueDirect                                                      True
# trafficSource_adContent                                                          NaN
# trafficSource_adwordsClickInfo.page                                              NaN
# trafficSource_adwordsClickInfo.slot                                              NaN
# trafficSource_adwordsClickInfo.gclId                                             NaN
# trafficSource_adwordsClickInfo.adNetworkType                                     NaN
# trafficSource_adwordsClickInfo.isVideoAd                                         NaN
# timeOnSite_sum                                                                  86.0
# timeOnSite_min                                                                  15.0
# timeOnSite_max                                                                  43.0
# timeOnSite_mean                                                            28.666667

# %%
from datetime import datetime, timedelta
tr["date"] = pd.to_datetime(tr["date"], infer_datetime_format=True, format="%Y%m%d")
def getTimeFramewithFeatures(tr, k=1):

    tf = tr.loc[(tr['date'] >= min(tr['date']) + timedelta(days=168*(k-1))) 
              & (tr['date'] < min(tr['date']) + timedelta(days=168*k))]
    
    print(tf.shape)

    tf_fvid = set(tr.loc[(tr['date'] >= min(tr['date']) + timedelta(days=168*k + 46 )) 
                       & (tr['date'] < min(tr['date']) + timedelta(days=168*k + 46 + 62))]['fullVisitorId'])

    tf_returned = tf[tf['fullVisitorId'].isin(tf_fvid)]
    
    tf_tst = tr[tr['fullVisitorId'].isin(set(tf_returned['fullVisitorId']))
             & (tr['date'] >= min(tr['date']) + timedelta(days=168*k + 46))
             & (tr['date'] < min(tr['date']) + timedelta(days=168*k + 46 + 62))]
    
    tf_target = tf_tst.groupby('fullVisitorId')[['totals_totalTransactionRevenue']].sum().apply(np.log1p, axis=1).reset_index()
    tf_target['ret'] = 1
    tf_target.rename(columns={'totals_totalTransactionRevenue': 'target'}, inplace=True)
    
    tf_nonret = pd.DataFrame()
    tf_nonret['fullVisitorId'] = list(set(tf['fullVisitorId']) - tf_fvid)    
    tf_nonret['target'] = 0
    tf_nonret['ret'] = 0
    
    tf_target = pd.concat([tf_target, tf_nonret], axis=0).reset_index(drop=True)
    # len(set(tf['fullVisitorId'])), len(set(tf_target['fullVisitorId']))
    tf_maxdate = max(tf['date'])
    tf_mindate = min(tf['date'])

    tf = tf.groupby('fullVisitorId').agg({
            'geoNetwork_networkDomain': {'networkDomain': lambda x: x.dropna().max()},
            'geoNetwork_city': {'city': lambda x: x.dropna().max()},
            'device_operatingSystem': {'operatingSystem': lambda x: x.dropna().max()},
            'geoNetwork_metro': {'metro': lambda x: x.dropna().max()},
            'geoNetwork_region': {'region': lambda x: x.dropna().max()},
            'channelGrouping': {'channelGrouping': lambda x: x.dropna().max()},
            'trafficSource_referralPath': {'referralPath': lambda x: x.dropna().max()},
            'geoNetwork_country': {'country': lambda x: x.dropna().max()},
            'trafficSource_source': {'source': lambda x: x.dropna().max()},
            'trafficSource_medium': {'medium': lambda x: x.dropna().max()},
            'trafficSource_keyword': {'keyword': lambda x: x.dropna().max()},
            'device_browser':  {'browser': lambda x: x.dropna().max()},
            'trafficSource_adwordsClickInfo.gclId': {'gclId': lambda x: x.dropna().max()},
            'device_deviceCategory': {'deviceCategory': lambda x: x.dropna().max()},
            'geoNetwork_continent': {'continent': lambda x: x.dropna().max()},
            'totals_timeOnSite': {'timeOnSite_sum': lambda x: x.dropna().sum(),
                                  'timeOnSite_min': lambda x: x.dropna().min(), 
                                  'timeOnSite_max': lambda x: x.dropna().max(),
                                  'timeOnSite_mean': lambda x: x.dropna().mean()},
            'totals_pageviews': {'pageviews_sum': lambda x: x.dropna().sum(),
                                 'pageviews_min': lambda x: x.dropna().min(), 
                                 'pageviews_max': lambda x: x.dropna().max(),
                                 'pageviews_mean': lambda x: x.dropna().mean()},
            'totals_hits': {'hits_sum': lambda x: x.dropna().sum(), 
                            'hits_min': lambda x: x.dropna().min(), 
                            'hits_max': lambda x: x.dropna().max(), 
                            'hits_mean': lambda x: x.dropna().mean()},
            'visitStartTime': {'visitStartTime_counts': lambda x: x.dropna().count()},
            'totals_sessionQualityDim': {'sessionQualityDim': lambda x: x.dropna().max()},
            'trafficSource_isTrueDirect': {'isTrueDirect': lambda x: x.dropna().max()},
            'totals_newVisits': {'newVisits_max': lambda x: x.dropna().max()},
            'device_isMobile': {'isMobile': lambda x: x.dropna().max()},
            'visitNumber': {'visitNumber_max' : lambda x: x.dropna().max()}, 
            'totals_totalTransactionRevenue':  {'totalTransactionRevenue_sum':  lambda x:x.dropna().sum()},
            'totals_transactions' : {'transactions' : lambda x:x.dropna().sum()},
            'date': {'first_ses_from_the_period_start': lambda x: x.dropna().min() - tf_mindate,
                     'last_ses_from_the_period_end': lambda x: tf_maxdate - x.dropna().max(),
                     'interval_dates': lambda x: x.dropna().max() - x.dropna().min(),
                     'unqiue_date_num': lambda x: len(set(x.dropna())) },            
                    })

    tf.columns = tf.columns.droplevel()

    tf = pd.merge(tf, tf_target, left_on='fullVisitorId', right_on='fullVisitorId')
    return tf

# %%
###Getting parts of train-set
print('Get 1st train part')
tr1 = getTimeFramewithFeatures(tr, k=1)
tr1.to_pickle(PATH/'tr1_clean')
# Out:
# Get 1st train part
# (3832, 56)
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# <ipython-input-21-4ec809e448f9> in <module>
#       1 ###Getting parts of train-set
#       2 print('Get 1st train part')
# ----> 3 tr1 = getTimeFramewithFeatures(tr, k=1)
#       4 tr1.to_pickle(PATH/'tr1_clean')
#
# <ipython-input-20-8ba7d4e2d305> in getTimeFramewithFeatures(tr, k)
#      31     tf_mindate = min(tf['date'])
#      32
# ---> 33     tf = tf.groupby('fullVisitorId').agg({
#      34             'geoNetwork_networkDomain': {'networkDomain': lambda x: x.dropna().max()},
#      35             'geoNetwork_city': {'city': lambda x: x.dropna().max()},
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     943         func = maybe_mangle_lambdas(func)
#     944
# --> 945         result, how = aggregate(self, func, *args, **kwargs)
#     946         if how is None:
#     947             return result
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/aggregation.py in aggregate(obj, arg, *args, **kwargs)
#     564     elif is_dict_like(arg):
#     565         arg = cast(AggFuncTypeDict, arg)
# --> 566         return agg_dict_like(obj, arg, _axis), True
#     567     elif is_list_like(arg):
#     568         # we require a list, but not an 'str'
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/aggregation.py in agg_dict_like(obj, arg, _axis)
#     722             # {'ra' : { 'A' : 'mean' }}
#     723             if isinstance(v, dict):
# --> 724                 raise SpecificationError("nested renamer is not supported")
#     725             elif isinstance(selected_obj, ABCSeries):
#     726                 raise SpecificationError("nested renamer is not supported")
#
# SpecificationError: nested renamer is not supported
